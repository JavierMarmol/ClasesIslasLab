# %%
from pylab import *
# %matplotlib inline

# %%
def func(x):
    # tabs son importantes!
    y = x**2
    return y

# %%
x = linspace(0,4)
y = func(x)
plot(x,y)

# %%
def func2(a):
    # tabs son importantes!
    x = linspace(0,a)
    y = x**3
    plot(x,y, 'red')

# %%
func2(1)

# %%
a = "hola mundo"
def hola():
    a = "hola de nuevo"
    print a
print a
hola()
# Out:
# hola mundo
# hola de nuevo

# %%
y = func(x)
z = func2(x)
plot(x,y)
plot(x,z)
xlim(0,1)
ylim(0,1)
# Out:
# (0, 1)

# %%
x = linspace(0,6)
puntosy = [1,3,2,5,0.2]
puntosx = [0,1,2,3,4]
plot(puntosx, puntosy,'o')
plot(x,func(x))

# %%
def func3(x,exponente):
    return x**exponente

# %%
for i in range(8):
    y = func3(x,i)
    plot(x,y)

# %%
range(3)
# Out:
# [0, 1, 2]

# %% [markdown]
# Esto saca un array

# %%
arange(0,2,0.5) # comments
# Out:
# array([ 0. ,  0.5,  1. ,  1.5])

# %%
platillos = [100,130,30]
len(platillos)
# Out:
# 3

# %%
def cuenta(platillos,propina):
    total = 0
    for i in range(len(platillos)):
        total += platillos[i]
        
    total = total + total*propina
    print total

# %%
platillos = [50,23,40,121,154]
propina = 0.11
cuenta(platillos,propina)
# Out:
# 430.68
